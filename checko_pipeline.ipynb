# %%
import os
import first


BASE_DIR = os.path.normpath(os.getcwd())
EACH_COMPANY_LIMIT = 2     # В конфиг

# %%
# first.prepare_input()

# %%
first.fetch_req_match_city()
# Out:
# Create C:\Users\user\Documents\Python Scripts\checko2\out.xlsx: OK
# 1: request to api with key: "G0MXVZRpkKmHSZxf", name: "Леруа Мерлен"
# 1 (Attempt #1) with key: "G0MXVZRpkKmHSZxf" - Fail
# 1: request to api with key: "1CEIl0crWoTxxKzC", name: "Леруа Мерлен"
# 1 (Attempt #2) with key: "1CEIl0crWoTxxKzC" - Fail
# 1: request to api with key: "KpOF72aqQIXcWFtT", name: "Леруа Мерлен"
# 1: successful request to api with key: "KpOF72aqQIXcWFtT, name: "Леруа Мерлен"!
# 1: write data to xlsx file with name: "Леруа Мерлен"
# 1: clean data with name: "Леруа Мерлен"
# 2: Remove api key: "KpOF72aqQIXcWFtT" from stack
# 2: request to api with key: "1CEIl0crWoTxxKzC", name: "SCS Group ltd."
# 2 (Attempt #1) with key: "1CEIl0crWoTxxKzC" - Fail
# 2: request to api with key: "KpOF72aqQIXcWFtT", name: "SCS Group ltd."
# 2: successful request to api with key: "KpOF72aqQIXcWFtT, name: "SCS Group ltd."!
# 2: write data to xlsx file with name: "SCS Group ltd."
# ...

# %%
first.fetch_unmatched_city()
# Out:
# Cannot create file: C:\Users\user\Documents\Python Scripts\checko2\out.xlsx, file already exists
# C:\Users\user\Documents\Python Scripts\checko2\first.py:90: FutureWarning: Setting the `book` attribute is not part of the public API, usage can give unexpected or corrupted results and will be removed in a future version
#   writer.book = workbook
#                                                 Название
# 0                                           Леруа Мерлен
# 13                                        SCS Group ltd.
# 674                                           Северсталь
# 1220                  Мираторг, Агропромышленный холдинг
# 1738                                            ДОБРОЦЕН
# 2637                                          Ridex GmbH
# 3440                                       Мясницкий ряд
# 3750                                         ИК СИБИНТЕК
# 3850                                          OPEN group
# 5104                          АгроТерра, группа компаний
# ...

# %%
import second
second.main()
# Out:
# Cannot create file: C:\Users\user\Documents\Python Scripts\checko2\out_inn.xlsx, file already exists
# 1: request to api with key: "G0MXVZRpkKmHSZxf", inn: "5029069967"
# 1: failed request to api with key: "G0MXVZRpkKmHSZxf"!
# 1: Remove api key: "G0MXVZRpkKmHSZxf" from stack
# 1: request to api with key: "KpOF72aqQIXcWFtT", inn: "5029069967"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 import second
# ----> 2 second.main()
#
# File ~\Documents\Python Scripts\checko2\second.py:49, in main()
#      47 print(f'{index + 1}: request to api with key: "{key}", inn: "{inn}"')
#      48 data, err = request_to_api(url, key, inn)
# ---> 49 if err == False:
#      50     print(f'{index + 1}: successful request to api with key: "{key}, inn: "{inn}"!')
#      51     print(f'{index + 1}: write data to xlsx file with inn: "{inn}"')
#
# ...

# %%
# del
import pandas as pd
df = pd.read_excel(os.path.join(BASE_DIR, "checko.xlsx"))
print(len(df))
# Out:
# 723

# %%
df.head()
# Out:
#                             Название             Город  \
# 0                       Леруа Мерлен            Россия
# 1                     SCS Group ltd.       Владивосток
# 2             МАГНИТ, Розничная сеть         Краснодар
# 3  ОКЕЙ – Федеральная розничная сеть   Санкт-Петербург
# 4                              Delko  Набережные Челны
#
#                            Сайт                        Сайт.1  \
# 0  http://rabota.leroymerlin.ru  http://rabota.leroymerlin.ru
# 1           http://www.scsg.ru/           http://www.scsg.ru/
# 2     http://www.magnit-info.ru     http://www.magnit-info.ru
# 3       http://www.okmarket.ru/       http://www.okmarket.ru/
# 4          http://www.del-ko.ru          http://www.del-ko.ru
#
#                                             описание  Контакты  Руководство  \
# 0  \nLeroy Merlin (в России «Леруа Мерлен») — фра...       NaN          NaN
# 1  \nSCS Group — международная группа компаний, ц...       NaN          NaN
# ...
